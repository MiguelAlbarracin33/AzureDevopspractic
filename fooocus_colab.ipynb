# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelAlbarracin33/AzureDevopspractic/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 15.2 MB/s eta 0:00:00
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 5458, done.
# remote: Counting objects: 100% (2630/2630), done.
# remote: Compressing objects: 100% (335/335), done.
# remote: Total 5458 (delta 2380), reused 2310 (delta 2295), pack-reused 2828
# Receiving objects: 100% (5458/5458), 32.30 MiB | 29.61 MiB/s, done.
# Resolving deltas: 100% (3237/3237), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.865
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 10.5MB/s]
# ...
